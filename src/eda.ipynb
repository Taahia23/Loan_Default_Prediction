# %%
! pip install ydata-profiling dtale

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('../data/Loan_default.csv')
data.sample(5)
# Out:
#             LoanID  Age  Income  LoanAmount  CreditScore  MonthsEmployed  \
# 48947   FLGYWJU7JD   36  119160      203706          427              32
# 228215  3GE4TOWAS3   29   35730       79132          770              90
# 191530  CP3S7UVO26   32   99261       50363          557              71
# 110507  DT295TFQDB   54   23811      178177          376              57
# 225275  4T7NSH4RPY   40   95950       64428          621              66
#
#         NumCreditLines  InterestRate  LoanTerm  DTIRatio   Education  \
# 48947                4          7.72        60      0.35         PhD
# 228215               2          8.84        12      0.33  Bachelor's
# 191530               1         16.57        24      0.37         PhD
# 110507               3          8.04        36      0.34         PhD
# 225275               4         14.60        12      0.26  Bachelor's
#
#        EmploymentType MaritalStatus HasMortgage HasDependents LoanPurpose  \
# ...

# %%
#  to create a data summary report i use ydata profiling

from ydata_profiling import ProfileReport

profile = ProfileReport(data, title = 'Loan Default Prediction')
profile.to_file("Loan_Default_Prediction.html")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       1 #  data summary report
#       3 from ydata_profiling import ProfileReport
# ----> 5 profile = ProfileReport(data, title = 'Loan Default Prediction')
#       6 profile.to_file("Loan_Default_Prediction.html")
#
# NameError: name 'data' is not defined

# %%
# use dtale to  develop a dashboard for data visualization
import dtale

d = dtale.show(data)
d.open_browser()

# %%
d.kill()
# Out:
# 2025-02-05 03:53:42,781 - INFO     - Executing shutdown...
# 2025-02-05 03:53:42,790 - INFO     - Not running with the Werkzeug Server, exiting by searching gc for BaseWSGIServer
